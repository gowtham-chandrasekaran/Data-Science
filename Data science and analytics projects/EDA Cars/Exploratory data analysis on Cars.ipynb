# %%
import pandas as pd

# %%
data = pd.read_csv(r"D:\Data analytics projects\EDA Cars\Cars_V2_data.csv")

# %%
data
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0      NaN                      NaN    NaN     NaN        NaN       NaN
# 1    Acura                      MDX    SUV    Asia        All  $36,945
# 2    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 3    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 4    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# ..     ...                      ...    ...     ...        ...       ...
# 424  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 425  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 426  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 427  Volvo                      V40  Wagon  Europe      Front  $26,135
# 428  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice Engine Size Cylinders  Horsepower  MPG (City)  MPG (Highway)  \
# ...

# %%
import os
os.chdir("D:\Data analytics projects\EDA Cars")

# %%
data.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0    NaN             NaN    NaN    NaN        NaN       NaN       NaN
# 1  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 2  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 3  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 4  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
#
#   Engine Size Cylinders  Horsepower  MPG (City)  MPG (Highway)  Weight (LBS)  \
# 0         (L)       NaN         NaN         NaN            NaN           NaN
# 1         3.5         6       265.0        17.0           23.0        4451.0
# 2           2         4       200.0        24.0           31.0        2778.0
# 3         2.4         4       200.0        22.0           29.0        3230.0
# 4         3.2         6       270.0        20.0           28.0        3575.0
#
#   Wheelbase  Length (IN)
# 0      (IN)          NaN
# 1       106        189.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429 entries, 0 to 428
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           428 non-null    object
#  1   Model          428 non-null    object
#  2   Type           428 non-null    object
#  3   Origin         428 non-null    object
#  4   DriveTrain     428 non-null    object
#  5   MSRP           428 non-null    object
#  6   Invoice        428 non-null    object
#  7   Engine Size    429 non-null    object
#  8   Cylinders      428 non-null    object
#  9   Horsepower     428 non-null    float64
#  10  MPG (City)     428 non-null    float64
#  11  MPG (Highway)  428 non-null    float64
#  12  Weight (LBS)   428 non-null    float64
#  13  Wheelbase      429 non-null    object
#  14  Length (IN)    428 non-null    float64
# dtypes: float64(5), object(10)
# memory usage: 50.4+ KB

# %%
#Drop unimportant columns
drop_cols = ['MSRP','Invoice'] #list
data = data.drop(drop_cols,axis = 1)

# %%
data.dropna()
# Out:
#       Make                    Model   Type  Origin DriveTrain Engine Size  \
# 1    Acura                      MDX    SUV    Asia        All         3.5
# 2    Acura           RSX Type S 2dr  Sedan    Asia      Front           2
# 3    Acura                  TSX 4dr  Sedan    Asia      Front         2.4
# 4    Acura                   TL 4dr  Sedan    Asia      Front         3.2
# 5    Acura               3.5 RL 4dr  Sedan    Asia      Front         3.5
# ..     ...                      ...    ...     ...        ...         ...
# 424  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front         2.4
# 425  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front         2.3
# 426  Volvo               S80 T6 4dr  Sedan  Europe      Front         2.9
# 427  Volvo                      V40  Wagon  Europe      Front         1.9
# 428  Volvo                     XC70  Wagon  Europe        All         2.5
#
#     Cylinders  Horsepower  MPG (City)  MPG (Highway)  Weight (LBS) Wheelbase  \
# ...

# %%
data
# Out:
#       Make                    Model   Type  Origin DriveTrain Engine Size  \
# 0      NaN                      NaN    NaN     NaN        NaN         (L)
# 1    Acura                      MDX    SUV    Asia        All         3.5
# 2    Acura           RSX Type S 2dr  Sedan    Asia      Front           2
# 3    Acura                  TSX 4dr  Sedan    Asia      Front         2.4
# 4    Acura                   TL 4dr  Sedan    Asia      Front         3.2
# ..     ...                      ...    ...     ...        ...         ...
# 424  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front         2.4
# 425  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front         2.3
# 426  Volvo               S80 T6 4dr  Sedan  Europe      Front         2.9
# 427  Volvo                      V40  Wagon  Europe      Front         1.9
# 428  Volvo                     XC70  Wagon  Europe        All         2.5
#
#     Cylinders  Horsepower  MPG (City)  MPG (Highway)  Weight (LBS) Wheelbase  \
# ...

# %%
#Remove duplicate rows
data = data.drop_duplicates(keep='first')

# %%
data
# Out:
#       Make                    Model   Type  Origin DriveTrain Engine Size  \
# 0      NaN                      NaN    NaN     NaN        NaN         (L)
# 1    Acura                      MDX    SUV    Asia        All         3.5
# 2    Acura           RSX Type S 2dr  Sedan    Asia      Front           2
# 3    Acura                  TSX 4dr  Sedan    Asia      Front         2.4
# 4    Acura                   TL 4dr  Sedan    Asia      Front         3.2
# ..     ...                      ...    ...     ...        ...         ...
# 424  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front         2.4
# 425  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front         2.3
# 426  Volvo               S80 T6 4dr  Sedan  Europe      Front         2.9
# 427  Volvo                      V40  Wagon  Europe      Front         1.9
# 428  Volvo                     XC70  Wagon  Europe        All         2.5
#
#     Cylinders  Horsepower  MPG (City)  MPG (Highway)  Weight (LBS) Wheelbase  \
# ...

# %% [markdown]
# This implies that there are no duplicate rows.

# %%
data.shape
# Out:
# (429, 13)

# %%
data.describe()
# Out:
#        Horsepower  MPG (City)  MPG (Highway)  Weight (LBS)  Length (IN)
# count  428.000000  428.000000     428.000000    428.000000   428.000000
# mean   215.885514   20.060748      26.843458   3577.953271   186.362150
# std     71.836032    5.238218       5.741201    758.983215    14.357991
# min     73.000000   10.000000      12.000000   1850.000000   143.000000
# 25%    165.000000   17.000000      24.000000   3104.000000   178.000000
# 50%    210.000000   19.000000      26.000000   3474.500000   187.000000
# 75%    255.000000   21.250000      29.000000   3977.750000   194.000000
# max    500.000000   60.000000      66.000000   7190.000000   238.000000

# %%
data_sort_MPG = data.sort_values(by = 'MPG (City)',ascending = False)
data_sort_MPG
# Out:
#            Make                                   Model    Type  Origin  \
# 151       Honda              Insight 2dr (gas/electric)  Hybrid    Asia
# 374      Toyota                Prius 4dr (gas/electric)  Hybrid    Asia
# 150       Honda  Civic Hybrid 4dr manual (gas/electric)  Hybrid    Asia
# 405  Volkswagen                       Jetta GLS TDI 4dr   Sedan  Europe
# 156       Honda                            Civic HX 2dr   Sedan    Asia
# ..          ...                                     ...     ...     ...
# 217  Land Rover                            Discovery SE     SUV  Europe
# 115       Dodge            Viper SRT-10 convertible 2dr  Sports     USA
# 119        Ford                       Excursion 6.8 XLT     SUV     USA
# 167      Hummer                                      H2     SUV     USA
# 0           NaN                                     NaN     NaN     NaN
#
#     DriveTrain Engine Size Cylinders  Horsepower  MPG (City)  MPG (Highway)  \
# ...

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'Engine Size',
#        'Cylinders', 'Horsepower', 'MPG (City)', 'MPG (Highway)',
#        'Weight (LBS)', 'Wheelbase', 'Length (IN)'],
#       dtype='object')

# %%
def min_max_values(col):
    top = data[col].idxmax() #return id of max value under that column
    top_obs = pd.DataFrame(data.loc[top]) #Getting the row from that index to display
    
    bottom = data[col].idxmin() #return id of min value under that column
    bottom_obs = pd.DataFrame(data.loc[bottom]) #Getting the row from that index to display
    
    min_max_obs = pd.concat([top_obs,bottom_obs],axis = 1)
    return min_max_obs

# %%
min_max_values('MPG (City)') #passing column name to above function to retrieve max and min value of that particular column and to get the total rows
# Out:
#                                       151                119
# Make                                Honda               Ford
# Model          Insight 2dr (gas/electric)  Excursion 6.8 XLT
# Type                               Hybrid                SUV
# Origin                               Asia                USA
# DriveTrain                          Front                All
# Engine Size                             2                6.8
# Cylinders                               3                 10
# Horsepower                             73                310
# MPG (City)                             60                 10
# MPG (Highway)                          66                 13
# Weight (LBS)                         1850               7190
# Wheelbase                              95                137
# Length (IN)                           155                227

# %% [markdown]
# From above, we can see that Honda Hybrid has the max mileage in city and Ford XLT has the minimum mileage in city

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data['MPG (City)'],10)
# Out:
# (array([ 31., 195., 142.,  44.,   9.,   4.,   0.,   1.,   0.,   2.]),
#  array([10., 15., 20., 25., 30., 35., 40., 45., 50., 55., 60.]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns

# %%
sns.distplot(data['MPG (City)'],10) #Probability density function curve; area under curve is 1
# Out:
# C:\Users\monster\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MPG (City)', ylabel='Density'>

# %%
make_table = data.groupby('Make').size()

# %%
make_table
# Out:
# Make
# Acura             7
# Audi             19
# BMW              20
# Buick             9
# Cadillac          8
# Chevrolet        27
# Chrysler         15
# Dodge            13
# Ford             23
# GMC               8
# Honda            17
# Hummer            1
# Hyundai          12
# Infiniti          8
# Isuzu             2
# Jaguar           12
# Jeep              3
# Kia              11
# Land Rover        3
# Lexus            11
# Lincoln           9
# MINI              2
# Mazda            11
# Mercedes-Benz    26
# Mercury           9
# Mitsubishi       13
# Nissan           17
# Oldsmobile        3
# Pontiac          11
# Porsche           7
# Saab              7
# Saturn            8
# Scion             2
# Subaru           11
# Suzuki            8
# Toyota           28
# Volkswagen       15
# Volvo            12
# dtype: int64

# %%
make_table.plot(title="Car Make")
# Out:
# <AxesSubplot:title={'center':'Car Make'}, xlabel='Make'>

# %% [markdown]
# We can see above that the distribution from different makes are well distributed.

# %%
cars_numerical = data.select_dtypes(include = ['int64','float64']) #Taking out all numerical data into separate table

# %%
cars_numerical
# Out:
#      Horsepower  MPG (City)  MPG (Highway)  Weight (LBS)  Length (IN)
# 0           NaN         NaN            NaN           NaN          NaN
# 1         265.0        17.0           23.0        4451.0        189.0
# 2         200.0        24.0           31.0        2778.0        172.0
# 3         200.0        22.0           29.0        3230.0        183.0
# 4         270.0        20.0           28.0        3575.0        186.0
# ..          ...         ...            ...           ...          ...
# 424       197.0        21.0           28.0        3450.0        186.0
# 425       242.0        20.0           26.0        3450.0        186.0
# 426       268.0        19.0           26.0        3653.0        190.0
# 427       170.0        22.0           29.0        2822.0        180.0
# 428       208.0        20.0           27.0        3823.0        186.0
#
# [429 rows x 5 columns]

# %%
cars_numerical.hist(bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'Horsepower'}>,
#         <AxesSubplot:title={'center':'MPG (City)'}>],
#        [<AxesSubplot:title={'center':'MPG (Highway)'}>,
#         <AxesSubplot:title={'center':'Weight (LBS)'}>],
#        [<AxesSubplot:title={'center':'Length (IN)'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
cars_correlation = cars_numerical.corr()['Horsepower'] #We are seeing correlation of horsepower with other numerical columns

# %%
cars_correlation
# Out:
# Horsepower       1.000000
# MPG (City)      -0.676699
# MPG (Highway)   -0.647195
# Weight (LBS)     0.630796
# Length (IN)      0.381554
# Name: Horsepower, dtype: float64

# %% [markdown]
# Negative shows inverse relation and positive vice versa

# %% [markdown]
# # Now we are going to show the correlation of MPG (City) with other columns using pairplot of seaborn

# %%
for i in range(0,len(cars_numerical.columns),5):
    sns.pairplot(cars_numerical,y_vars=['Horsepower'],x_vars=cars_numerical.columns[i:i+5])

# %% [markdown]
# # Correlation using heatmap

# %%
corr = cars_numerical.drop('Horsepower',axis=1).corr()
sns.heatmap(corr[(corr>=0.5)|(corr<=-0.5)], cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot=True, annot_kws={"size":20}, square=True);

# %% [markdown]
# We are setting correlation threshold from 0.5 to -0.5

# %%
plt.figure(figsize=(16, 6))
sns.heatmap(cars_numerical.corr(),annot=True,vmax=1.0,vmin=-1.0) #Simpler way to show correlation for any dataframe
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='Type', y='MPG (City)', data=data)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='MPG (City)'>

# %% [markdown]
# We can see above that Hybrid type of cars have the best mileage.

# %%
sns.boxplot(x='Origin', y='MPG (City)', data=data)
# Out:
# <AxesSubplot:xlabel='Origin', ylabel='MPG (City)'>

# %% [markdown]
# Asia Origin cars have more mileage.

# %%
sns.regplot(data['Length (IN)'],data['MPG (City)'])
# Out:
# C:\Users\monster\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Length (IN)', ylabel='MPG (City)'>

# %% [markdown]
# So from above regression analysis plot, we can say that with increase in length, MPG decreases. There are more points near the line which shows that there is a strong relation between these two.
