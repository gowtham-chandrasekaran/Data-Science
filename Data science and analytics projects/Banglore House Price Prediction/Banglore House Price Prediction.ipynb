# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"D:\Data analytics projects\Banglore House Price Prediction\Bengaluru_House_Data.csv")

# %%
data
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
data.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
data.shape
# Out:
# (13320, 9)

# %%
data.area_type.value_counts()
# Out:
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: area_type, dtype: int64

# %% [markdown]
# We are assuming that we dont need certain columns. So we drop them.

# %%
df = data.drop(['area_type','availability','society','balcony'],axis='columns')
df
# Out:
#                        location       size total_sqft  bath   price
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                      Kothanur      2 BHK       1200   2.0   51.00
# ...                         ...        ...        ...   ...     ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00
# 13316             Richards Town      4 BHK       3600   5.0  400.00
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00
# 13319              Doddathoguru      1 BHK        550   1.0   17.00
#
# [13320 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
df2 = df.dropna()

# %%
df2.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# dtype: int64

# %%
df2['size'].value_counts()
# Out:
# 2 BHK         5198
# 3 BHK         4286
# 4 Bedroom      818
# 4 BHK          577
# 3 Bedroom      546
# 1 BHK          531
# 2 Bedroom      329
# 5 Bedroom      296
# 6 Bedroom      191
# 1 Bedroom      105
# 8 Bedroom       84
# 7 Bedroom       83
# 5 BHK           57
# 9 Bedroom       46
# 6 BHK           30
# 7 BHK           17
# 1 RK            13
# 10 Bedroom      12
# 9 BHK            8
# 8 BHK            5
# 11 Bedroom       2
# 10 BHK           2
# 11 BHK           2
# 12 Bedroom       1
# 13 BHK           1
# 19 BHK           1
# 18 Bedroom       1
# 16 BHK           1
# 43 Bedroom       1
# 14 BHK           1
# 27 BHK           1
# Name: size, dtype: int64

# %% [markdown]
# We are now going to remove bhk, bedroom and only take the number and store it in a new column.

# %%
df2['bhk'] = df2['size'].apply(lambda x: int(x.split(' ')[0]))
# Out:
# <ipython-input-25-eadc3504d97e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['bhk'] = df2['size'].apply(lambda x: int(x.split(' ')[0]))

# %%
df2 #We have created a new column
# Out:
#                        location       size total_sqft  bath   price  bhk
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00    4
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00    3
# 4                      Kothanur      2 BHK       1200   2.0   51.00    2
# ...                         ...        ...        ...   ...     ...  ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00    5
# 13316             Richards Town      4 BHK       3600   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00    2
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00    4
# 13319              Doddathoguru      1 BHK        550   1.0   17.00    1
#
# [13246 rows x 6 columns]

# %%
df2.bhk.value_counts()
# Out:
# 2     5527
# 3     4832
# 4     1395
# 1      649
# 5      353
# 6      221
# 7      100
# 8       89
# 9       54
# 10      14
# 11       4
# 27       1
# 14       1
# 43       1
# 18       1
# 12       1
# 13       1
# 16       1
# 19       1
# Name: bhk, dtype: int64

# %% [markdown]
# Let us have a look at the total sqft

# %%
df2.total_sqft.unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %% [markdown]
# Above we see a value like '1133 - 1384' which is a range. We can convert this as mean value and substitute it there.

# %%
def is_float(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
df2[df2.total_sqft.apply(is_float)] #This returns all proper float values under total sqft
# Out:
#                        location       size total_sqft  bath   price  bhk
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00    4
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00    3
# 4                      Kothanur      2 BHK       1200   2.0   51.00    2
# ...                         ...        ...        ...   ...     ...  ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00    5
# 13316             Richards Town      4 BHK       3600   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00    2
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00    4
# 13319              Doddathoguru      1 BHK        550   1.0   17.00    1
#
# [13056 rows x 6 columns]

# %%
df2[~df2.total_sqft.apply(is_float)] #This returns all improper float values under total sqft
# Out:
#                  location   size   total_sqft  bath    price  bhk
# 30              Yelahanka  4 BHK  2100 - 2850   4.0  186.000    4
# 122                Hebbal  4 BHK  3067 - 8156   4.0  477.000    4
# 137    8th Phase JP Nagar  2 BHK  1042 - 1105   2.0   54.005    2
# 165              Sarjapur  2 BHK  1145 - 1340   2.0   43.490    2
# 188              KR Puram  2 BHK  1015 - 1540   2.0   56.800    2
# ...                   ...    ...          ...   ...      ...  ...
# 12975          Whitefield  2 BHK   850 - 1060   2.0   38.190    2
# 12990      Talaghattapura  3 BHK  1804 - 2273   3.0  122.000    3
# 13059              Harlur  2 BHK  1200 - 1470   2.0   72.760    2
# 13265               Hoodi  2 BHK  1133 - 1384   2.0   59.135    2
# 13299          Whitefield  4 BHK  2830 - 2882   5.0  154.500    4
#
# [190 rows x 6 columns]

# %%
df2[~df2.total_sqft.apply(is_float)].head(10)
# Out:
#                location       size      total_sqft  bath    price  bhk
# 30            Yelahanka      4 BHK     2100 - 2850   4.0  186.000    4
# 122              Hebbal      4 BHK     3067 - 8156   4.0  477.000    4
# 137  8th Phase JP Nagar      2 BHK     1042 - 1105   2.0   54.005    2
# 165            Sarjapur      2 BHK     1145 - 1340   2.0   43.490    2
# 188            KR Puram      2 BHK     1015 - 1540   2.0   56.800    2
# 410             Kengeri      1 BHK  34.46Sq. Meter   1.0   18.500    1
# 549         Hennur Road      2 BHK     1195 - 1440   2.0   63.770    2
# 648             Arekere  9 Bedroom       4125Perch   9.0  265.000    9
# 661           Yelahanka      2 BHK     1120 - 1145   2.0   48.130    2
# 672        Bettahalsoor  4 Bedroom     3090 - 5002   4.0  445.000    4

# %% [markdown]
# In above two cells, we see string values and ranges.
# In this project, we are only going to remove strings and have the ranges. Ranges can be converted to their mean

# %%
df3 = df2.copy() #We are creating a copy for further cleaning

# %%
def sqft_to_num(x):
    tokens = x.split('-')
    if len(tokens) == 2:
        return (float(tokens[0]) + float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

# %% [markdown]
# In the above function, we are taking each value from the total_sqft column and trying to split with '-' to get a list of numbers only which is still a string. Next we convert the string to float and find average of the two and return it.
# If the above operation does not perform, it will come down to just convert to float which is the case for all numbers that are entering into the function. This will throw an error if the x contains a string value other than '-' like 34.46Sq. Meter. For them, return none.

# %%
df3['total_sqft'] = df3['total_sqft'].apply(sqft_to_num)

# %% [markdown]
# To check if it has worked we can see the previous record's index that had string values.

# %%
df3.loc[30]
# Out:
# location      Yelahanka
# size              4 BHK
# total_sqft         2475
# bath                  4
# price               186
# bhk                   4
# Name: 30, dtype: object

# %%
df3.loc[410]
# Out:
# location      Kengeri
# size            1 BHK
# total_sqft        NaN
# bath                1
# price            18.5
# bhk                 1
# Name: 410, dtype: object

# %% [markdown]
# It has worked properly

# %%
df4 = df3.copy()

# %%
df4
# Out:
#                        location       size  total_sqft  bath   price  bhk
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13315                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13316             Richards Town      4 BHK      3600.0   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13318           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13319              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
# [13246 rows x 6 columns]

# %%
df4['price_per_sqft'] = df4['price']*100000/df4['total_sqft'] #We are creating a new column to store price per sqft

# %%
df4
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13315                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13316             Richards Town      4 BHK      3600.0   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13318           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13319              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0         3699.810606
# 1         4615.384615
# ...

# %%
df4.location.value_counts().sort_values(ascending=False).head(40)
# Out:
# Whitefield                  534
# Sarjapur  Road              392
# Electronic City             302
# Kanakpura Road              266
# Thanisandra                 233
# Yelahanka                   210
# Uttarahalli                 186
# Hebbal                      176
# Marathahalli                175
# Raja Rajeshwari Nagar       171
# Bannerghatta Road           152
# Hennur Road                 150
# 7th Phase JP Nagar          149
# Haralur Road                141
# Electronic City Phase II    131
# Rajaji Nagar                106
# Chandapura                   98
# Bellandur                    96
# KR Puram                     88
# Hoodi                        88
# Electronics City Phase 1     87
# Yeshwanthpur                 85
# Begur Road                   84
# Sarjapur                     81
# Harlur                       79
# Kasavanhalli                 79
# Hormavu                      74
# Banashankari                 74
# Kengeri                      73
# ...

# %% [markdown]
# We have 1304 locations and there are locations that have only 1 data. We will now take all locations that have less than or equal to 10 and call it as other locations.

# %%
location_stats = df4.groupby('location')['location'].agg('count').sort_values(ascending=False)

# %%
location_stats #This is same as value_counts.
# Out:
# location
# Whitefield                            534
# Sarjapur  Road                        392
# Electronic City                       302
# Kanakpura Road                        266
# Thanisandra                           233
#                                      ...
# Konappana Agrahara                      1
# Kodanda Reddy Layout                    1
# Kirloskar layout, Basaveshwarnagar      1
# Kengeri Satellite Town Stage II         1
#  Anekal                                 1
# Name: location, Length: 1304, dtype: int64

# %%
len(location_stats[location_stats<=10])
# Out:
# 1063

# %%
location_less_than_10 = location_stats[location_stats<=10]
location_less_than_10
# Out:
# location
# Ganga Nagar                           10
# Nagappa Reddy Layout                  10
# BTM 1st Stage                         10
# Dodsworth Layout                      10
# Kalkere                               10
#                                       ..
# Konappana Agrahara                     1
# Kodanda Reddy Layout                   1
# Kirloskar layout, Basaveshwarnagar     1
# Kengeri Satellite Town Stage II        1
#  Anekal                                1
# Name: location, Length: 1063, dtype: int64

# %%
len(df4.location.unique())
# Out:
# 1304

# %% [markdown]
# We are going to remove them and store it as other.

# %%
df4['location'] = df4.location.apply(lambda x: 'other' if x in location_less_than_10 else x)
len(df4.location.unique())
# Out:
# 242

# %%
df4.location.value_counts()
# Out:
# other               2896
# Whitefield           534
# Sarjapur  Road       392
# Electronic City      302
# Kanakpura Road       266
#                     ...
# Narayanapura          11
# Thyagaraja Nagar      11
# Banjara Layout        11
# Tindlu                11
# Marsur                11
# Name: location, Length: 242, dtype: int64

# %% [markdown]
# # Now we are going to remove some outliers

# %% [markdown]
# Suppose we know that in Banglore, typically a size of a bedroom is above 300sqft.
# We are going to remove the records that have less than 300 per room.
# To find per room, we calculate total_sqft/bhk.

# %%
df4
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13315                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13316                     other      4 BHK      3600.0   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13318           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13319              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0         3699.810606
# 1         4615.384615
# ...

# %%
df5 = df4[~((df4['total_sqft']/df4['bhk'])<300)]

# %%
df4[(df4['total_sqft']/df4['bhk'])<300]
# Out:
#                location       size  total_sqft  bath  price  bhk  \
# 9                 other  6 Bedroom      1020.0   6.0  370.0    6
# 45           HSR Layout  8 Bedroom       600.0   9.0  200.0    8
# 58        Murugeshpalya  6 Bedroom      1407.0   4.0  150.0    6
# 68                other  8 Bedroom      1350.0   7.0   85.0    8
# 70                other  3 Bedroom       500.0   3.0  100.0    3
# ...                 ...        ...         ...   ...    ...  ...
# 13277             other  7 Bedroom      1400.0   7.0  218.0    7
# 13279             other  6 Bedroom      1200.0   5.0  130.0    6
# 13281   Margondanahalli  5 Bedroom      1375.0   5.0  125.0    5
# 13303    Vidyaranyapura  5 Bedroom       774.0   5.0   70.0    5
# 13311  Ramamurthy Nagar  7 Bedroom      1500.0   9.0  250.0    7
#
#        price_per_sqft
# 9        36274.509804
# 45       33333.333333
# 58       10660.980810
# 68        6296.296296
# 70       20000.000000
# ...               ...
# ...

# %%
df4.shape
# Out:
# (13246, 7)

# %%
df5.shape
# Out:
# (12502, 7)

# %% [markdown]
# We have removed outliers

# %%
df5.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft
# 0     3699.810606
# 1     4615.384615
# 2     4305.555556
# 3     6245.890861
# 4     4250.000000

# %%
df5.price_per_sqft.describe()
# Out:
# count     12456.000000
# mean       6308.502826
# std        4168.127339
# min         267.829813
# 25%        4210.526316
# 50%        5294.117647
# 75%        6916.666667
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %% [markdown]
# It shows that min cost per sqft is 267 RS which is very unlikely.
